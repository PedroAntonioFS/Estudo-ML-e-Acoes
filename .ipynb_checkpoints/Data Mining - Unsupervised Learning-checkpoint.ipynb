# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('transformation_result_1_year_SD.csv')

# %%
df.head()
# Out:
#      P/L  P/VP  EV/EBITDA  EV/EBIT  P/EBIT    VPA  P/ATIVO   LPA      P/SR  \
# 0  -6.64  0.95   0.410000     0.40   -5.23   5.71     0.89 -0.82  4.360000
# 1  13.23  2.38  16.605213    11.31   11.47   3.52     2.35  0.63  7.512599
# 2  26.50  4.83  16.605213    18.08   17.38   3.29     1.60  0.60  1.600000
# 3  35.62  3.15  17.650000    20.61   21.30   4.29     1.26  0.38  5.040000
# 4   5.50  1.05   2.610000     3.06    3.89  16.22     0.35  3.09  0.280000
#
#    P/CAP.GIRO  ...    ROE    ROA   ROIC  Giro ativos  CAGR Receitas 5 anos  \
# 0        0.97  ... -14.30 -13.37 -18.17         0.20              8.991379
# 1       28.62  ...  17.96  17.80  17.86         0.00              8.991379
# 2        5.52  ...  18.21   6.05  10.32         1.00              8.991379
# 3        3.68  ...   8.84   3.54   6.03         0.25              8.991379
# 4        1.74  ...  19.07   6.36  20.12         1.27              8.991379
#
#    CAGR Lucros 5 anos     Open_0  Open_1  acoes  bdrs
# ...

# %%
df['Open_dif'] = df['Open_1'] - df['Open_0']
df.drop(['Open_1', 'Open_0'], axis=1, inplace=True)

# %%
for col in df.drop('Open_dif', axis=1).columns:
    x = df[[col, 'Open_dif']]
    km = KMeans(n_clusters=2)
    
    y = km.fit_predict(x)
    
    plt.scatter(
        x['Open_dif'][y == 0], x[col][y == 0],
        s=50, c='lightgreen',
        marker='s', edgecolor='black',
        label='cluster 1'
    )

    plt.scatter(
        x['Open_dif'][y == 1], x[col][y == 1],
        s=50, c='orange',
        marker='o', edgecolor='black',
        label='cluster 2'
    )
    
    plt.title("{} x Price in a Year".format(col))
    plt.xlabel('Price')
    plt.ylabel(col)
    plt.legend(scatterpoints=1)
    plt.grid()
    plt.show()
    print("cluster 1:{} / Cluster 2:{}\n".format(len(x[y == 0]), len(x[y == 1])))
# Out:
# cluster 1:4892 / Cluster 2:1
# cluster 1:4481 / Cluster 2:412
# cluster 1:4892 / Cluster 2:1
# cluster 1:4888 / Cluster 2:5
# cluster 1:4890 / Cluster 2:3
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4119 / Cluster 2:774
# cluster 1:4475 / Cluster 2:418
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4891 / Cluster 2:2
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4887 / Cluster 2:6
# cluster 1:4887 / Cluster 2:6
# cluster 1:4891 / Cluster 2:2
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4889 / Cluster 2:4
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1
# cluster 1:4892 / Cluster 2:1

# %%
for col in df.drop('Open_dif', axis=1).columns:
    x = df[[col, 'Open_dif']]
    km = KMeans(n_clusters=3)
    
    y = km.fit_predict(x)
    
    plt.scatter(
        x['Open_dif'][y == 0], x[col][y == 0],
        s=50, c='lightgreen',
        marker='s', edgecolor='black',
        label='cluster 1'
    )

    plt.scatter(
        x['Open_dif'][y == 1], x[col][y == 1],
        s=50, c='orange',
        marker='o', edgecolor='black',
        label='cluster 2'
    )

    plt.scatter(
        x['Open_dif'][y == 2], x[col][y == 2],
        s=50, c='blue',
        marker='o', edgecolor='black',
        label='cluster 3'
    )
    
    plt.title("{} x Price in a Year".format(col))
    plt.xlabel('Price')
    plt.ylabel(col)
    plt.legend(scatterpoints=1)
    plt.grid()
    plt.show()
    print("cluster 1:{} / Cluster 2:{}\n / Cluster 3:{}\n".format(len(x[y == 0]), len(x[y == 1]), len(x[y == 2])))
# Out:
# cluster 1:4884 / Cluster 2:1
#  / Cluster 3:8
# cluster 1:411 / Cluster 2:4481
#  / Cluster 3:1
# cluster 1:4891 / Cluster 2:1
#  / Cluster 3:1
# cluster 1:4884 / Cluster 2:8
#  / Cluster 3:1
# cluster 1:4884 / Cluster 2:1
#  / Cluster 3:8
# cluster 1:4853 / Cluster 2:1
#  / Cluster 3:39
# cluster 1:4886 / Cluster 2:1
#  / Cluster 3:6
# cluster 1:4572 / Cluster 2:1
#  / Cluster 3:320
# cluster 1:4880 / Cluster 2:1
#  / Cluster 3:12
# cluster 1:774 / Cluster 2:4111
#  / Cluster 3:8
# cluster 1:4475 / Cluster 2:417
#  / Cluster 3:1
# cluster 1:4567 / Cluster 2:1
#  / Cluster 3:325
# cluster 1:4577 / Cluster 2:1
#  / Cluster 3:315
# cluster 1:4890 / Cluster 2:2
#  / Cluster 3:1
# cluster 1:4567 / Cluster 2:1
#  / Cluster 3:325
# cluster 1:4572 / Cluster 2:1
#  / Cluster 3:320
# cluster 1:4567 / Cluster 2:1
#  / Cluster 3:325
# cluster 1:4567 / Cluster 2:1
#  / Cluster 3:325
# cluster 1:4886 / Cluster 2:4
#  / Cluster 3:3
# cluster 1:4885 / Cluster 2:6
#  / Cluster 3:2
# ...
